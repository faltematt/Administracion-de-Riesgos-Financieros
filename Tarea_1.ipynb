# %% [markdown]
# #Tarea 1 - Administración del Riesgo Financiero

# %% [markdown]
# ##Sector/Temática

# %% [markdown]
# Tanto en la actualidad como en los tiempos pasados, la minería ha desempeñado un rol de suma importancia en el desarrollo económico y social de los países. Específicamente en Chile, la minería de cobre representa una de las mayores actividades económicas, exportando aproximadamente un 30% de la producción global.
#
# Ahora bien, durante los últimos años, el litio, gracias a sus propiedades químicas, ha ido tomando gran fuerza en la industria principalmente eléctrica. Este elemento metálico blando, de color blanco/plata, permite el almacenamiento de grandes densidades de energia eléctrica en espacios relativamente pequeños. Por lo que lo hace un elemento ideal para las baterías de, por ejemplo, autos eléctricos.
#
# En este sentido, el sector que se analizará en el presente trabajo será el minero, pero específicamente el del litio. Para esto se profundizará en una de las mayores compañías productoras de este metal, Soquimich (Sociedad Química y Minera de Chile), de ahora en adelante SQM.
#
# En relación a lo anterior, el Gerente General de SQM, Ricardo Ramos expresó en el último informe de utilidades del segundo semestre de 2022 lo siguiente: “Estamos cercanos a llegar a las 180.000 toneladas métricas en nuestra capacidad de litio. Hoy estamos trabajando para completar una capacidad de carbonato de litio de 210.000 toneladas métricas de producto codiciado, de alta calidad y valor agregado que se producirá en Chile. Seguimos comprometidos a reducir nuestro uso de salmuera y agua a través de la tecnología y la innovación continua. Esta nueva capacidad nos permitirá producir productos de litio de alto valor agregado para la producción de más de 5 millones de vehículos eléctricos”.

# %% [markdown]
# ![Captura.png](data:image/png;base64,...)

# %% [markdown]
# Maxwell, P. et al, 2019. Lithium and Chile: looking back and looking forward. *Mineral Economics*, p. 15.

# %% [markdown]
# ##Motivación

# %% [markdown]
# Como se expresó anteriormente, la industria del litio ha ido tomando fuerza los últimos años gracias al desarrollo tecnológico de las baterías eléctricas. Dado que es un sector que todavía está en desarrollo, tanto en las políticas productivas y extractivas, como también en el desarrollo de la cadena de suministro y logística, es una área que merece ser analizada a fondo.
#
# En cuanto a SQM, es una empresa con una amplia trayectoria tanto en Chile como en el mundo presente en industrias estratégicas para el desarrollo sostenible, tales como salud, alimentación, tecnología y energías limpias. Esta se enfoca en 5 principales negocios: Nutrición vegetal de especialidad, yodo y derivados, litio y derivados, potasio y sales solares. Por lo que SQM, una empresa chilena que ejerce liderazgo mundial en las áreas donde se encuentra, es digna de ser analizada en cuanto al tema tratado y la metodologia aplicada.

# %% [markdown]
# ##Contexto

# %% [markdown]
# Para el analisis contextual de la tematica, se definen 4 activos relacionados. Y se muestra sus respectivas series de tiempo.

# %% [markdown]
# ###Precio de acciones de SQM en NYSE: empresa base a analizar

# %%
# !pip install yfinance
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.74-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed requests-2.28.1 yfinance-0.1.74
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)

# %%
import plotly.graph_objs as go
import yfinance as yf

#data = yf.download(tickers=stock_price, period = ‘how_many_days’, interval = ‘how_long_between_each_check’, rounding= bool)
data = yf.download(tickers='SQM', period = '5y', interval = '1d', rounding= True)
fig = go.Figure()
fig.add_trace(go.Candlestick())
fig.add_trace(go.Candlestick(x=data.index,open = data['Open'], high=data['High'], low=data['Low'], close=data['Close'], name = 'market data'))
fig.update_layout(title = 'SQM share price', yaxis_title = 'Stock Price (USD)')
fig.update_xaxes(
rangeslider_visible=True,
rangeselector=dict(
buttons=list([
dict(count=11, label='1d', step="day", stepmode="backward"),
dict(count=15, label='15d', step="day", stepmode="backward"),
dict(count=1, label='1m', step="month", stepmode="backward"),
dict(count=6, label='6m', step="month", stepmode="backward"),
dict(step="all")
])
)
)
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d4218640-dc7e-468e-a723-b8905ab485c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4218640-dc7e-468e-a723-b8905ab485c1")) {                    Plotly.newPlot(                        "d4218640-dc7e-468e-a723-b8905ab485c1",                        [{"type":"candlestick"},{"close":[58.06,58.97,61.95,57.43,58.7,56.48,52.97,52.66,55.17,55.29,55.66,55.8,57.5,59.44,59.18,58.94,58.54,58.84,57.81,57.99,59.9,61.45,59.96,60.6,59.29,59.3,59.4,60.99,59.84,60.11,59.7,59.79,59.74,61.28,58.05,58.85,58.94,59.83,59.82,57.96,57.76,59.23,57.93,56.58,57.26,59.8,54.54,57.33,56.52,56.42,54.26,54.5,52.42,54.32,54.41,52.57,52.16,50.2,51.94,50.95,51.92,51.96,53.7,52.26,52.67,56.85,58.43,59.53,58.99,59.64,59.12,58.81,59.06,59.37,61.5,61.42,61.72,63.07,62.92,62.36,61.81,63.9,62.73,58.59,59.55,59.02,56.93,57.84,56.36,55.47,57.0,55.9,54.98,56.0,56.38,55.77,53.06,51.15,53.56,54.84,53.57,54.16,55.09,54.3,55.76,55.93,54.56,55.23,55.18,56.47,58.39,53.71,52.56,49.9,46.73,47.85,46.75,48.4,49.8,50.26,51.7,51.24,50.81,50.66,48.81,48.66,47.62,47.42,47.7,46.82,47.43,47.8,47.45,46.9,49.15,48.0,49.09,50.09,51.66,51.37,51.8,52.75,52.79,53.25,53.0,52.46,53.41,54.57,56.51,56.59,55.95,56.05,54.53,55.1,55.26,54.89,55.09,54.51,53.85,54.15,53.3,52.85,53.51,56.52,57.05,56.0,57.16,58.16,54.96,54.94,55.14,53.87,53.5,50.29,51.33,50.71,51.48,52.13,51.45,53.35,52.44,52.24,51.67,51.6,51.48,50.6,50.28,50.3,49.95,49.57,48.07,47.41,47.78,49.18,48.16,48.76,47.57,47.89,48.05,46.98,47.51,47.92,48.47,48.83,48.77,48.16,48.69,48.57,47.8,48.41,47.83,46.99,47.3,46.15,46.7,47.23,46.75,46.88,46.62,48.27,47.5,48.18,48.85,46.87,47.25,48.09,47.91,46.8,45.68,45.14,43.76,44.63,44.78,44.44,44.82,45.1,42.86,43.59,43.18,42.54,42.77,41.96,42.61,42.2,41.47,42.18,43.57,43.05,43.21,44.51,45.51,45.9,47.05,46.7,48.02,48.4,48.45,47.58,46.76,46.74,46.14,45.72,46.25,46.77,47.07,45.94,45.02,45.3,44.72,42.83,42.75,43.09,42.92,43.28,42.18,41.21,41.54,40.89,40.77,40.91,41.67,42.26,41.11,42.21,43.81,47.14,47.4,46.72,46.53,46.28,45.47,45.0,44.03,43.27,43.88,44.87,44.57,43.62,41.9,42.95,42.72,42.53,41.79,43.12,44.02,44.0,46.43,45.25,44.76,43.96,43.55,43.18,43.51,43.34,42.68,41.28,40.89,40.96,38.47,38.34,36.94,39.04,38.92,38.16,38.3,38.52,37.24,39.04,39.48,40.9,41.25,42.19,41.97,42.71,42.06,42.42,43.16,42.5,42.36,42.35,42.25,42.4,41.9,42.1,42.15,42.66,42.49,42.89,42.73,42.6,42.61,41.55,40.71,40.16,40.42,41.03,41.34,41.27,41.95,43.55,44.37,44.67,44.16,45.0,41.22,39.33,38.99,39.36,38.53,37.64,37.7,38.68,39.27,40.25,40.28,40.81,40.29,39.68,38.98,39.34,38.16,38.11,37.72,37.43,37.98,38.44,38.74,38.09,38.01,38.61,38.86,38.66,38.51,38.57,37.9,37.77,37.27,37.43,38.58,38.08,37.08,36.49,35.86,35.53,36.47,36.0,35.64,35.14,36.05,36.29,36.44,35.35,34.5,34.56,34.99,34.32,34.38,34.25,33.69,32.9,32.7,33.17,32.69,30.8,30.36,29.28,29.38,29.77,30.33,31.26,32.41,31.69,31.22,31.42,31.86,32.99,31.78,32.27,31.22,31.43,31.37,31.27,31.53,31.26,30.79,30.37,30.93,31.55,31.11,30.55,29.85,29.79,30.12,29.12,28.79,29.01,29.55,30.14,30.55,30.23,29.82,30.0,30.8,30.85,30.79,30.5,30.12,30.25,29.72,30.04,29.49,27.82,27.09,26.52,26.21,26.76,28.81,28.59,27.18,27.62,26.34,26.01,26.85,26.57,26.26,25.43,23.71,22.98,23.06,23.15,23.38,23.89,24.64,23.8,23.98,24.73,24.83,25.25,26.26,27.48,27.73,27.61,28.04,27.61,27.64,27.98,27.85,27.9,27.12,27.46,27.91,27.89,27.79,27.55,27.09,27.09,27.0,26.59,26.1,26.17,27.02,28.17,27.58,27.87,27.92,28.46,28.37,27.54,27.55,27.57,27.8,27.31,28.19,27.88,27.21,27.18,28.68,28.73,28.09,27.43,28.1,26.65,27.07,24.92,24.09,23.67,24.57,24.04,23.75,23.41,23.26,23.3,23.41,23.19,24.16,23.83,23.72,23.7,24.14,24.37,24.86,24.94,24.99,25.76,26.62,26.72,27.07,27.9,27.56,27.32,27.35,27.76,27.72,28.14,26.85,26.34,26.69,26.93,26.72,27.13,27.86,27.91,27.3, ...

# %% [markdown]
# ###Precio de acciones de Albemarle (ALB) en NYSE: empresa americana, competencia

# %%
data = yf.download(tickers='ALB', period = '5y', interval = '1d', rounding= True)
fig = go.Figure()
fig.add_trace(go.Candlestick())
fig.add_trace(go.Candlestick(x=data.index,open = data['Open'], high=data['High'], low=data['Low'], close=data['Close'], name = 'market data'))
fig.update_layout(title = 'Albemarle share price', yaxis_title = 'Stock Price (USD)')
fig.update_xaxes(
rangeslider_visible=True,
rangeselector=dict(
buttons=list([
dict(count=11, label='1d', step="day", stepmode="backward"),
dict(count=15, label='15d', step="day", stepmode="backward"),
dict(count=1, label='1m', step="month", stepmode="backward"),
dict(count=6, label='6m', step="month", stepmode="backward"),
dict(step="all")
])
)
)
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8651042b-9768-43f0-842b-ee6447ccfd63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8651042b-9768-43f0-842b-ee6447ccfd63")) {                    Plotly.newPlot(                        "8651042b-9768-43f0-842b-ee6447ccfd63",                        [{"type":"candlestick"},{"close":[null,127.29,131.02,134.65,136.08,134.89,134.29,128.89,128.42,130.02,132.32,136.31,136.62,137.42,138.22,139.66,137.19,136.55,137.77,137.42,137.3,138.94,140.16,139.41,139.66,139.49,140.78,138.53,138.72,138.53,139.04,139.08,139.51,140.89,142.33,136.91,140.04,141.97,143.13,144.58,140.84,140.62,143.37,137.65,134.54,135.33,136.21,135.4,136.7,135.25,137.06,136.23,136.89,131.95,134.32,132.15,129.35,127.99,127.48,129.08,130.6,131.14,130.36,130.1,127.58,129.57,132.08,132.02,131.33,128.65,129.29,129.04,128.43,128.45,127.89,131.53,131.79,130.22,131.72,137.45,135.44,132.96,134.69,133.52,128.0,126.95,117.91,116.01,113.53,113.0,112.4,116.9,114.41,111.68,111.37,111.59,109.2,105.51,105.15,107.54,106.63,105.18,107.72,111.59,108.45,111.72,114.61,112.24,114.58,113.01,113.68,118.75,110.1,111.57,100.43,96.01,95.02,96.44,100.14,100.05,99.28,101.76,102.99,103.13,100.33,98.07,98.37,96.91,95.32,97.47,94.11,93.24,94.36,93.43,89.56,92.74,88.96,90.42,91.6,95.77,91.8,91.22,92.33,93.31,93.39,95.5,96.87,96.63,98.79,98.59,97.75,97.34,95.78,95.46,96.55,96.95,96.96,97.62,97.84,97.89,100.06,100.11,100.72,101.75,98.39,98.54,99.24,100.81,102.35,104.8,104.92,104.07,102.34,101.84,95.02,94.82,93.03,93.59,93.47,94.26,94.44,94.65,95.67,95.22,95.37,95.37,95.74,94.18,93.66,93.33,92.87,91.4,91.61,91.97,93.46,91.96,92.52,93.41,93.64,94.33,93.48,96.62,94.78,95.54,95.98,95.81,94.68,95.35,95.57,94.96,96.97,96.74,96.21,93.9,90.92,90.9,91.79,93.06,93.26,92.42,94.2,91.01,92.02,92.61,92.66,92.81,98.77,100.76,98.5,95.63,97.33,95.54,97.06,95.44,95.54,94.84,94.53,93.77,96.0,96.89,96.94,96.72,95.05,95.52,96.57,96.45,97.66,97.19,97.39,98.84,99.46,100.61,100.9,102.45,103.06,105.49,106.6,105.42,104.94,102.53,101.32,100.95,99.78,100.84,101.85,104.04,104.22,103.06,102.25,97.28,95.67,94.36,95.09,96.05,97.14,96.32,95.67,95.63,97.26,96.16,93.64,95.41,95.24,95.16,97.12,99.22,105.42,106.44,106.21,107.79,107.99,105.87,102.38,98.07,99.2,99.94,102.7,100.98,99.61,95.74,95.52,96.77,96.61,95.43,96.62,96.42,96.32,98.46,93.19,91.19,88.65,89.04,89.08,88.78,87.94,84.97,80.51,81.03,79.8,76.16,74.84,73.13,76.28,77.22,76.74,77.07,78.11,72.69,76.24,76.58,77.33,76.84,77.27,77.41,76.97,73.64,73.93,75.29,76.63,75.37,73.92,74.02,76.58,77.09,78.32,80.21,80.73,81.3,81.94,81.32,82.19,80.64,81.01,80.86,80.45,81.73,80.42,81.37,83.13,82.81,89.26,89.18,91.57,91.0,92.28,91.29,90.79,88.49,87.93,86.37,84.6,82.97,85.51,85.47,86.21,84.73,85.42,86.43,85.23,84.44,85.51,82.72,81.58,81.04,80.15,81.17,81.98,84.2,82.9,84.21,85.55,86.14,86.94,84.78,85.55,82.71,83.66,82.26,83.21,82.1,82.57,82.17,79.05,76.8,74.87,75.56,75.71,75.06,74.07,76.09,77.05,77.05,75.85,72.58,72.61,72.63,68.55,70.22,69.58,69.41,67.76,67.78,68.5,67.96,66.34,66.8,67.43,65.8,65.57,63.3,65.05,67.54,67.37,68.46,69.08,70.93,73.43,72.18,72.76,70.88,71.24,70.77,68.94,69.49,68.34,68.01,67.79,69.16,69.52,70.41,70.33,69.87,71.54,70.51,70.19,70.62,70.49,70.58,72.63,72.42,73.05,72.64,73.0,74.47,73.18,74.58,75.53,74.61,74.58,73.09,73.6,72.96,69.59,68.68,65.41,65.45,67.59,73.49,70.25,67.38,68.45,64.29,61.66,63.09,64.92,64.17,65.91,63.22,59.95,60.81,59.3,59.32,60.49,61.73,60.23,61.31,62.97,63.23,65.36,68.28,69.25,69.28,69.28,68.84,67.76,67.4,68.29,68.86,68.22,67.89,68.3,67.19,68.14,69.52,68.31,66.57,67.23,66.32,65.68,63.7,63.6,65.46,68.91,67.56,67.87,67.58,68.22,67.13,67.24,66.79,67.46,69.45,63.59,63.74,63.03,62.67,60.74,64.49,67.7,67.37,66.72,71.39,67.98,67.73,65.31,65.18,65.54,66.14,67.1,66.46,65.05,65. ...

# %% [markdown]
# ###Precio de acciones de Pilbara Minerals (PLS) en AXS: empresa australiana.

# %%
data = yf.download(tickers='PLS.AX', period = '5y', interval = '1d', rounding= True)
fig = go.Figure()
fig.add_trace(go.Candlestick())
fig.add_trace(go.Candlestick(x=data.index,open = data['Open'], high=data['High'], low=data['Low'], close=data['Close'], name = 'market data'))
fig.update_layout(title = 'Pilbara Minerals share price', yaxis_title = 'Stock Price (AUD)')
fig.update_xaxes(
rangeslider_visible=True,
rangeselector=dict(
buttons=list([
dict(count=11, label='1d', step="day", stepmode="backward"),
dict(count=15, label='15d', step="day", stepmode="backward"),
dict(count=1, label='1m', step="month", stepmode="backward"),
dict(count=6, label='6m', step="month", stepmode="backward"),
dict(step="all")
])
)
)
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="27f6f729-5294-4858-988b-e4b42c97c856" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27f6f729-5294-4858-988b-e4b42c97c856")) {                    Plotly.newPlot(                        "27f6f729-5294-4858-988b-e4b42c97c856",                        [{"type":"candlestick"},{"close":[0.56,0.555,0.585,0.57,0.55,0.535,0.525,0.545,0.54,0.54,0.5475,0.635,0.66,0.645,0.655,0.715,0.785,0.765,0.755,0.765,0.78,0.805,0.855,0.83,0.8,0.77,0.75,0.76,0.795,0.805,0.76,0.78,0.805,0.81,0.85,0.845,0.845,0.88,0.89,0.93,0.98,1.025,1.005,1.005,0.91,0.95,0.925,0.925,0.94,0.99,0.965,0.975,1.01,0.985,1.035,1.055,1.03,1.02,0.95,0.925,0.885,0.95,0.935,0.94,0.96,1.0,1.025,1.15,1.195,1.19,1.14,1.12,1.165,1.14,1.115,1.18,1.18,1.185,1.195,1.185,1.22,1.22,1.14,1.175,1.165,1.125,1.065,1.005,0.99,0.94,1.01,1.015,1.01,1.03,0.98,0.945,0.945,0.915,0.86,0.8,0.85,0.82,0.815,0.795,0.87,0.835,0.845,0.83,0.84,0.83,0.805,0.835,0.855,0.85,0.83,0.92,0.915,0.88,0.83,0.845,0.825,0.865,0.87,0.895,0.91,0.925,0.97,0.93,0.92,0.905,0.905,0.905,0.875,0.855,0.88,0.845,0.825,0.84,0.82,0.81,0.805,0.795,0.84,0.805,0.8,0.81,0.81,0.795,0.83,0.87,0.895,0.89,0.885,0.88,0.89,0.92,0.93,0.93,0.925,0.915,0.925,0.915,0.91,0.905,0.91,0.91,0.93,0.92,0.95,0.935,0.94,0.905,0.895,0.88,0.865,0.885,0.9,0.895,0.92,0.9,0.905,0.915,0.915,0.9,0.885,0.88,0.87,0.885,0.89,0.9,0.885,0.9,0.905,0.895,0.895,0.88,0.87,0.865,0.865,0.865,0.885,0.91,0.905,0.935,0.99,1.05,1.06,1.105,1.07,1.025,1.025,1.01,0.985,1.03,1.01,0.995,0.965,0.95,0.93,0.905,0.88,0.885,0.845,0.9,0.905,0.88,0.87,0.885,0.88,0.865,0.855,0.86,0.835,0.86,0.85,0.825,0.825,0.825,0.815,0.85,0.86,0.84,0.82,0.805,0.8,0.805,0.775,0.705,0.77,0.76,0.765,0.77,0.77,0.765,0.79,0.79,0.8,0.855,0.88,0.925,0.875,0.88,0.885,0.9,0.915,0.9,0.865,0.86,0.85,0.825,0.835,0.82,0.79,0.79,0.79,0.795,0.795,0.78,0.785,0.825,0.8,0.79,0.76,0.76,0.74,0.77,0.785,0.795,0.86,0.83,0.85,0.855,0.855,0.835,0.855,0.825,0.82,0.83,0.835,0.85,0.825,0.79,0.85,0.835,0.815,0.83,0.84,0.84,0.84,0.84,0.815,0.785,0.78,0.775,0.76,0.76,0.745,0.76,0.745,0.755,0.72,0.685,0.635,0.58,0.62,0.62,0.625,0.625,0.625,0.725,0.705,0.73,0.72,0.71,0.705,0.7,0.705,0.7,0.695,0.71,0.71,0.705,0.695,0.68,0.675,0.665,0.635,0.67,0.65,0.69,0.67,0.665,0.665,0.655,0.64,0.645,0.65,0.64,0.65,0.66,0.67,0.665,0.675,0.69,0.735,0.74,0.76,0.75,0.745,0.705,0.705,0.7,0.74,0.74,0.715,0.735,0.715,0.72,0.73,0.715,0.715,0.715,0.72,0.715,0.71,0.675,0.69,0.7,0.805,0.79,0.74,0.77,0.77,0.74,0.73,0.735,0.7,0.7,0.7,0.715,0.705,0.7,0.69,0.66,0.665,0.65,0.655,0.615,0.61,0.605,0.66,0.72,0.73,0.76,0.755,0.78,0.765,0.77,0.76,0.765,0.775,0.785,0.785,0.78,0.835,0.795,0.75,0.73,0.72,0.725,0.735,0.72,0.7,0.68,0.68,0.665,0.685,0.68,0.68,0.68,0.705,0.635,0.595,0.545,0.565,0.585,0.565,0.56,0.545,0.54,0.545,0.555,0.555,0.52,0.49,0.5,0.49,0.515,0.49,0.5,0.485,0.485,0.49,0.49,0.47,0.47,0.485,0.49,0.495,0.49,0.475,0.465,0.455,0.47,0.485,0.475,0.4625,0.425,0.425,0.46,0.49,0.475,0.485,0.515,0.47,0.46,0.445,0.445,0.425,0.415,0.385,0.36,0.35,0.35,0.35,0.35,0.35,0.35,0.35,0.325,0.33,0.34,0.34,0.35,0.34,0.335,0.345,0.34,0.34,0.345,0.345,0.34,0.34,0.33,0.325,0.325,0.32,0.31,0.295,0.29,0.29,0.295,0.305,0.305,0.3,0.31,0.32,0.315,0.3,0.295,0.285,0.285,0.295,0.285,0.28,0.28,0.31,0.3,0.3,0.325,0.345,0.38,0.35,0.335,0.335,0.335,0.325,0.32,0.305,0.305,0.305,0.295,0.31,0.295,0.295,0.31,0.31,0.305,0.3,0.3,0.3,0.29,0.285,0.275,0.28,0.275,0.265,0.26,0.26,0.255,0.27,0.27,0.26,0.255,0.26,0.265,0.255,0.26,0.265,0.29,0.28,0.305,0.31,0.295,0.315,0.3,0.33,0.34,0.35,0.39,0.36,0.35,0.38,0.385,0.365,0.375,0.365,0.36,0.335,0.335,0.295,0.295,0.285,0.31,0.345,0.325,0.325,0.325,0.32,0.32,0.31,0.305,0.3,0.2795,0.2981,0.2841,0.2888,0.2702,0.2655,0.2562,0.2469,0.2329,0.2422,0.2329,0.2329,0.2282,0 ...

# %% [markdown]
# ###Precio de “Lithium & Battery Tech ETF” (LIT):
#
# ETF que se basa en el indicador “Solactive Global Lithium Index”.

# %%
data = yf.download(tickers='LIT', period = '5y', interval = '1d', rounding= True)
fig = go.Figure()
fig.add_trace(go.Candlestick())
fig.add_trace(go.Candlestick(x=data.index,open = data['Open'], high=data['High'], low=data['Low'], close=data['Close'], name = 'market data'))
fig.update_layout(title = 'Lithium & Battery Tech ETF price', yaxis_title = 'Stock Price (USD)')
fig.update_xaxes(
rangeslider_visible=True,
rangeselector=dict(
buttons=list([
dict(count=11, label='1d', step="day", stepmode="backward"),
dict(count=15, label='15d', step="day", stepmode="backward"),
dict(count=1, label='1m', step="month", stepmode="backward"),
dict(count=6, label='6m', step="month", stepmode="backward"),
dict(step="all")
])
)
)
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="82f25fb2-f5d1-4517-825d-d6c56673a80e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82f25fb2-f5d1-4517-825d-d6c56673a80e")) {                    Plotly.newPlot(                        "82f25fb2-f5d1-4517-825d-d6c56673a80e",                        [{"type":"candlestick"},{"close":[37.85,38.67,39.28,38.42,37.95,37.09,36.0,36.24,36.93,36.96,37.41,37.68,38.27,39.14,39.62,39.03,38.88,39.15,39.05,39.05,39.66,39.92,39.47,39.61,39.48,39.44,39.49,39.59,39.01,38.94,38.98,38.96,39.21,39.86,39.07,39.15,39.53,40.01,40.69,40.31,40.31,40.45,39.81,38.89,39.57,39.63,39.45,40.13,40.21,40.45,40.06,40.22,39.62,39.89,39.55,38.98,38.1,37.32,37.55,37.9,38.28,38.31,38.85,38.62,38.75,39.76,39.91,40.06,39.71,39.87,39.63,39.82,38.83,38.76,39.67,39.88,39.84,40.5,41.08,40.86,40.31,40.45,40.67,39.83,39.96,38.46,38.16,38.02,38.28,38.34,38.65,38.58,38.27,37.67,37.54,36.89,35.45,34.17,34.97,35.15,34.1,34.5,35.52,35.37,36.2,36.76,36.26,36.12,35.97,36.43,37.23,35.96,35.62,34.22,33.54,33.62,33.61,34.41,34.37,34.64,35.5,35.76,35.67,35.71,35.59,35.49,34.69,34.56,34.81,33.9,33.21,33.71,33.28,32.54,32.98,32.18,32.42,32.54,33.17,32.7,32.59,33.11,33.03,33.28,33.41,33.38,33.42,33.86,33.94,33.73,33.47,33.07,32.74,33.0,33.17,33.05,33.1,32.99,33.17,33.59,33.76,33.68,33.77,33.96,34.07,34.14,33.94,34.28,34.8,34.45,34.81,34.3,34.18,33.27,33.4,33.05,33.33,33.24,33.61,33.96,33.9,34.46,34.25,34.25,34.37,34.39,34.02,34.09,33.87,33.45,32.57,32.8,32.63,33.03,32.59,32.62,32.41,32.44,32.52,32.36,32.43,32.39,32.74,33.11,33.31,32.76,33.09,33.17,32.6,32.91,32.77,32.6,32.48,31.88,32.02,32.37,32.54,32.53,32.26,32.53,32.19,32.19,32.6,32.33,32.43,32.91,32.91,32.23,31.61,31.84,31.21,31.51,31.6,31.61,31.93,31.91,31.52,31.91,32.5,32.43,32.57,32.05,32.1,31.67,31.25,31.08,30.98,31.02,31.18,31.45,31.7,32.0,32.13,32.41,32.94,33.32,33.68,33.69,33.48,33.32,33.36,32.95,33.2,33.2,33.25,32.87,32.3,32.18,31.51,30.36,29.72,30.38,30.53,31.04,30.67,30.05,30.12,30.29,29.92,28.91,29.71,29.35,29.16,29.77,30.28,31.48,31.88,31.83,32.11,32.44,32.07,31.72,30.95,31.04,31.19,31.74,31.68,31.46,30.41,30.57,30.3,30.74,30.71,31.48,31.36,31.39,32.22,31.2,30.79,30.05,29.92,29.83,30.19,30.13,29.54,28.74,28.63,28.12,27.24,26.93,26.49,27.49,27.45,26.91,26.98,27.08,26.26,27.26,27.75,28.1,28.26,28.42,28.29,28.1,28.0,28.16,28.18,28.29,27.8,27.69,27.69,28.2,28.07,28.14,28.44,28.46,28.85,28.95,29.09,29.08,28.58,28.34,28.29,28.25,28.38,28.39,28.66,28.93,29.16,29.62,29.78,30.42,30.24,30.32,29.93,29.72,29.4,29.3,29.13,28.54,28.29,28.68,28.5,28.66,28.48,28.62,28.62,28.58,28.29,28.77,27.98,27.78,27.89,27.72,28.0,28.3,28.89,28.9,29.13,29.18,29.34,29.46,29.17,29.42,29.1,29.15,28.97,29.16,29.4,29.06,28.85,28.59,28.03,27.72,27.8,27.77,27.61,27.25,27.8,28.29,27.89,27.73,27.37,27.09,27.18,26.08,26.19,26.36,26.23,25.64,25.35,25.63,25.55,24.97,24.9,24.79,24.6,24.72,24.62,24.69,25.37,25.15,25.23,25.69,25.97,26.34,25.82,26.13,25.82,25.92,25.92,25.82,26.12,26.11,25.98,25.91,25.97,25.95,26.09,26.2,26.08,26.23,26.08,25.72,25.54,25.73,25.71,26.07,26.23,26.22,26.11,26.14,26.42,26.41,26.63,26.8,25.99,26.06,25.89,25.94,25.87,25.22,24.91,23.89,23.92,24.29,25.16,24.87,24.32,24.43,23.69,23.4,23.66,23.92,23.92,24.01,23.33,22.72,22.77,22.61,22.78,23.06,23.37,23.1,23.31,23.75,23.91,24.24,24.45,24.92,25.05,25.22,25.01,24.96,24.88,24.92,25.04,24.93,24.49,24.31,24.3,24.27,24.37,24.28,23.88,23.89,23.91,23.85,23.53,23.56,23.84,24.48,24.23,24.36,24.34,24.49,24.3,24.37,24.38,24.45,24.92,24.77,25.13,25.07,25.1,24.9,25.75,26.45,26.34,26.18,26.68,26.42,26.34,25.73,25.45,25.37,25.75,25.65,25.54,25.17,25.15,25.06,25.39,25.47,25.54,25.42,25.49,25.33,25.34,25.47,25.71,25.75,25.97,26.22,26.76,26.73,26.93,27.28,27.18,27.32,27.45,27.57,27.53,27.66,27.5,27.18,27.34,27.7,27.32,27. ...

# %% [markdown]
# ###Precio del litio (commodity) en la bolsa de metales de londres (LME):

# %% [markdown]
# ![Captura.png](data:image/png;base64,...)

# %% [markdown]
# ##Caracterización de la Deuda

# %% [markdown]
# ###Bonos:

# %% [markdown]
# SQM ha emitido bonos tanto en el mercado chileno como internacionalmente:

# %% [markdown]
# ####Bonos internacionales:

# %% [markdown]
# * Serie 144A-S/2023:
#   * Monto emisión: US$300.000.000
#
#   * Emisión: 2013
#   * Estructura amortización: Bullet
#   * Vencimiento: 2023
#   * Tasa Cupón: 3.625% anual, compuesto semestralmente.
# * Serie 144A-S/2025:
#   * Monto emisión: US$250.000.000
#
#   * Emisión: 2014
#   * Estructura amortización: Bullet
#   * Vencimiento: 2025
#   * Tasa Cupón: 4.375% anual, compuesto semestralmente.
# * Serie 144A-S/2029:
#   * Monto emisión: US$450.000.000.
#
#   * Emisión: 2019
#   * Estructura amortización: Bullet
#   * Vencimiento: 2029
#   * Tasa Cupón: 4.25% anual, compuesto semestralmente.
# * Serie 144A-S/2050:
#   * Monto emisión: US$400.000.000
#
#   * Emisión: 2020
#   * Estructura amortización: Bullet
#   * Vencimiento: 2050
#   * Tasa Cupón: 4.25% anual, compuesto semestralmente.
# * Serie Verde 144A-S/2051:
#   * Monto emisión: US$700.000.000
#   * Emisión: 2021
#   * Estructura amortización: Bullet
#   * Vencimiento: 2051
#   * Tasa Cupón: 3.5% anual, compuesto semestralmente.

# %% [markdown]
# ####Bonos nacionales:

# %% [markdown]
# * Bono Serie "H"/2030:
#   * Monto emisión: UF 4.000.000
#   * Emisión: 2009
#   * Estructura amortización: Amortizado a partir de 2019
#   * Vencimiento: 2030
#   * Tasa cupón: 4.9% anual, compuesto semestralmente.
# * Bono Serie "O"/2033:
#   * Monto emisión: UF 1.500.000
#   * Emisión: 2012
#   * Estructura amortización: Bullet
#   * Vencimiento: 2033
#   * Tasa cupón: 3.8% anual, compuesto semestralmente.
# * Bono Serie "P"/2028:
#   * Monto emisión: UF 3.000.000
#   * Emisión: 2018
#   * Estructura amortización: Bullet
#   * Vencimiento: 2028
#   * Tasa cupón: 3.25% anual, compuesto semestralmente.
# * Bono Serie "Q"/2030:
#   * Monto emisión: UF 3.000.000
#   * Emisión: 2018
#   * Estructura amortización: Bullet
#   * Vencimiento: 2038
#   * Tasa cupón: 3.45% anual, compuesto semestralmente.

# %% [markdown]
# ###Acciones:

# %% [markdown]
# SQM se caracteriza por tener dos series o clases de acciones A y B, y transar en la bolsa de Santiago (SQM-A y SQM-B) y la de Nueva York (SQM) (Solo acciones serie B en esta última mediante ADS, American Depositary Shares). Estas series se diferencian en cuanto a su capacidad de elección de directores.
#
# Con fecha 22 de enero de 2021, SQM anunció una nueva emisión de 22.442.580 de acciones serie B, por un valor de US$1.100.000.000. Esta emisión tiene por objetivo financiar proyectos a gran escala que buscan duplicar la producción de litio.
#
# Número de acciones emitidas:
# * Serie A: 142.819.552
# * Serie B: 142.818.904
#
# Dividendos año 2021:
# * Provisorio 28 de mayo 2021: US$0,23797 por acción
#
# * Provisorio 1 de septiembre 2021: US$0,31439 por acción
#
# * Eventual 30 de diciembre 2021: US$1,40037 por acción.

# %% [markdown]
# ##Emisiones

# %% [markdown]
# Como fue mencionado anteriormente, la última emisión de acciones por parte de SQM ocurrió el 2021. Con una emisión de 22.442.580 de acciones serie B, por un valor de US$1.100.000.000.
#
# Esta emisión fue aprobada por la junta de accionistas el día 22 de enero de 2021.
# Los accionistas existentes obtuvieron derechos de preferencia para la compra de acciones, tanto los chilenos como los titulares de ADRs (acciones vendidas en NYSE), con un precio de ejercicio de US$50 por acción. Mediante este mecanismo, se usaron cerca del 96,6% de las opciones preferentes.
#
# Terminado el periodo de las opciones preferente, SQM vendió 754.373 acciones de la serie B restantes a un precio promedio de CLP 37.885 (aproximadamente US$54) por acción a través de 3 remates públicos realizados en la Bolsa de Comercio de Santiago.
#
# Con el proceso de emisión y aumento de capital completado, SQM logró recaudar aproximadamente US$1.100.000.000.

# %% [markdown]
# ##Derivados

# %% [markdown]
# Se llevó a cabo una valoracion de una opcion de compra de la accion de SQM transado en NYSE. El precio de ejercicio es 145 USD y la fecha de vencimiento es en enero de 2024.

# %%
from sympy import *
init_printing()

# %%
# Parámetros Bono
r, B = symbols('r B')
# Parámetros Acción
u, d, S0 = symbols('u d S0')
# Parámetros Bono
r, B = symbols('r B')
# Parámetros Acción
u, d, S0 = symbols('u d S0')
W = Matrix([[-B, -S0], [r*B, u*S0],[r*B, d*S0]])
W
pi_u, pi_d = symbols('pi_u pi_d')
pi = Matrix([[1],[pi_u],[pi_d]])
pi
NA=pi.transpose()*W
NA
# Solver tutorial
# https://docs.sympy.org/latest/modules/solvers/solvers.html
piNA=solve([NA[0],NA[1]],[pi_u,pi_d],dict=True)
piNA
# Out:
# ⎡⎧       -r + u          -d + r  ⎫⎤
# ⎢⎨π_d: ──────────, πᵤ: ──────────⎬⎥
# ⎣⎩     -d⋅r + r⋅u      -d⋅r + r⋅u⎭⎦

# %%
# Parámetros Opción
q3 = symbols('q3')
K = 145                       #strike
# Parámetros Bono
r, B = 1.0379, 98.98          #tasa libre de riesgoa dos años, valor par bono https://www.bloomberg.com/markets/rates-bonds/government-bonds/us
# Parámetros Acción
u, d, S0 = 1.5013, 0.4987, 113.52   #retorno favorable, retorno desfavorable (volatilidad implicada 50,13%) y precio del activo https://finance.yahoo.com/quote/SQM/options?date=1705622400&p=SQM
W = Matrix([[-B, -S0, -q3], [r*B, u*S0, max(0,u*S0-K)],[r*B, d*S0, max(0,d*S0-K)]])
W
# Out:
# ⎡  -98.98     -113.52       -q₃   ⎤
# ⎢                                 ⎥
# ⎢102.731342  170.427576  25.427576⎥
# ⎢                                 ⎥
# ⎣102.731342  56.612424       0    ⎦

# %%
u,r,d = symbols('u r d')
Prices=Matrix([[1],[piNA[0][pi_u]],[piNA[0][pi_d]]]).transpose()*W
Prices
# Out:
# ⎡102.731342⋅(-d + r)   102.731342⋅(-r + u)          170.427576⋅(-d + r)   56.6
# ⎢─────────────────── + ─────────────────── - 98.98  ─────────────────── + ────
# ⎣     -d⋅r + r⋅u            -d⋅r + r⋅u                   -d⋅r + r⋅u
#
# 12424⋅(-r + u)                 25.427576⋅(-d + r)⎤
# ────────────── - 113.52  -q₃ + ──────────────────⎥
# -d⋅r + r⋅u                         -d⋅r + r⋅u    ⎦

# %%
Prices.subs([(d,0.4987),(u,1.5013),(r,1.0379)])
# Out:
# [0  1.4210854715202e-14  13.1756373396411 - q₃]

# %% [markdown]
# En consecuencia, el valor de la opcion de compra, con un strike de USD145 y vencimiento el 19 de enero de 2024, es de USD13.1756
